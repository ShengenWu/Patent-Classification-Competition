# %%
# !pip install --upgrade tencentcloud-sdk-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.3 MB 7.9 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.4 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
from tencentcloud.common.exception.tencent_cloud_sdk_exception import TencentCloudSDKException
from tencentcloud.tmt.v20180321 import tmt_client, models
from tencentcloud.common.abstract_client import AbstractClient
from tencentcloud.common import credential
from tencentcloud.common.profile.client_profile import ClientProfile
from tencentcloud.common.profile.http_profile import HttpProfile
import pandas as pd
import time
import os
import base64
import json

# %%
def tencent_translate(content, src='zh', tgt="en"):
    """腾讯翻译引擎, 详细API接口：https://cloud.tencent.com/document/api/551/15619"""
    time.sleep(0.1)
    try:
        cred = credential.Credential("*********", "*********") #自己申请的api和密钥
        httpProfile = HttpProfile()
        httpProfile.endpoint = "tmt.tencentcloudapi.com"
        clientProfile = ClientProfile()
        clientProfile.httpProfile = httpProfile
        client = tmt_client.TmtClient(cred, "ap-shanghai", clientProfile)
        # if len(content) >= 200:
        #     content = content[:200]
        req = models.TextTranslateRequest()
        params = {
            "SourceText": content,
            "Source": src,
            "Target": tgt,
            "ProjectId": 0
        }
        req.from_json_string(json.dumps(params))
        resp = client.TextTranslate(req)
        result = resp.to_json_string()
        result = eval(result)
        return result["TargetText"]
    except TencentCloudSDKException as err:
        print(err.message)
        return None

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def read_json(input_file):
    """Reads a json list file."""
    with open(input_file, "r") as f:
        reader = f.readlines()
    return [json.loads(line.strip()) for line in reader]

df = pd.DataFrame.from_records(read_json('/content/drive/MyDrive/Colab Notebooks/Academic-paper-classification/data/testA.json'))
df.head(10)
# Out:
#                                  id                     title  \
# 0  003fd481e65ddc070e38ae05002e16e2      一种耐磨、抗粘钢复合涂层、制备方法及应用
# 1  549a1cd8228bd10f18395a0625fcc70d  一种用于提高橡胶抗湿滑性的树脂的制备方法及其应用
# 2  f09c4c0332f8966400e06f4def9f1a6d   有机硅改性丙烯酸树脂超亲水防雾涂料及其制作方法
# 3  06598dd8f3ab092acf2a55dce8be5621         一种空调系统及其控制方法、控制装置
# 4  e70177ba6a54d08abecd80a60fdd9f52       资源申请、分配方法，UE及网络控制单元
# 5  963b07699949643c631bff293d764108           一种多元复合导电层及其制备方法
# 6  700be7358887b3a794a12547a3671a03        一种基于三维波束的室内多用户定位方法
# 7  481982b61009f135c2a5ccaba6864a48           一种三维可调机器人零件焊接工装
# 8  170bfb8eb35e21ac71af8d2700ab00b0                  冷却塔遮光板装置
# 9  cb620b03551e40594e0fe10f80f447c5  一种含氟纳米微球与高导热率材料复合涂料及制备方法
#
#             assignee                                           abstract
# 0     安徽马钢表面技术股份有限公司  本发明公开了一种耐磨、抗粘钢复合涂层、制备方法及应用，包括基体和基体上由内到外依次设置的过渡...
# 1       江苏麒祥高新材料有限公司  本发明公开了一种用于提高橡胶抗湿滑性的树脂的制备方法，第一步：将R树脂和B官能团化合物进行反...
# ...

# %%
df['title_en'] = df.title.apply(tencent_translate)
# Out:
# Reduce the frequency
# Reduce the frequency

# %%
df.head()
# Out:
#                                  id                     title        assignee  \
# 0  003fd481e65ddc070e38ae05002e16e2      一种耐磨、抗粘钢复合涂层、制备方法及应用  安徽马钢表面技术股份有限公司
# 1  549a1cd8228bd10f18395a0625fcc70d  一种用于提高橡胶抗湿滑性的树脂的制备方法及其应用    江苏麒祥高新材料有限公司
# 2  f09c4c0332f8966400e06f4def9f1a6d   有机硅改性丙烯酸树脂超亲水防雾涂料及其制作方法            重庆大学
# 3  06598dd8f3ab092acf2a55dce8be5621         一种空调系统及其控制方法、控制装置      海尔智家股份有限公司
# 4  e70177ba6a54d08abecd80a60fdd9f52       资源申请、分配方法，UE及网络控制单元      中兴通讯股份有限公司
#
#                                             abstract  \
# 0  本发明公开了一种耐磨、抗粘钢复合涂层、制备方法及应用，包括基体和基体上由内到外依次设置的过渡...
# 1  本发明公开了一种用于提高橡胶抗湿滑性的树脂的制备方法，第一步：将R树脂和B官能团化合物进行反...
# 2  本发明涉及涂料制造领域，本发明公开了一种含有磺酸季铵盐的有机硅改性丙烯酸树脂超亲水低温防雾涂...
# 3  本发明涉及空调领域，公开了一种空调系统，包括室外机和太阳能供热系统，所述太阳能供热系统包括：...
# 4  本发明实施例公开了一种资源申请方法及装置，所述方法包括：向网络控制单元发送低时延业务信息；接...
#
#                                             title_en
# 0  Wear-resistant and anti-adhesive steel composi...
# 1  Preparation method and application of resin fo...
# ...

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Academic-paper-classification/dataset/testA_en_title.csv',index=False)

# %%
df['assignee_en'] = df.assignee.apply(tencent_translate)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-bb9e7f980dac> in <module>
# ----> 1 df['assignee_en'] = df.assignee.apply(tencent_translate)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# ...

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Academic-paper-classification/dataset/testA_en_ta.csv',index=False)
